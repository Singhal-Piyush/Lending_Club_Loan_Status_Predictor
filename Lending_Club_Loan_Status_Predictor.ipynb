# %% [markdown]
# # Lending Clun Loan Status Predictor

# %% [markdown]
# #### Importing Lirbraries and packages

# %%
# importing Libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

import gc
import time

# %%
# Display Parameters 
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",151)
pd.set_option("display.max_colwidth",300)
pd.set_option("display.float_format",lambda x: '%.2f' %x)

# %% [markdown]
# #### Loading Dataset

# %%
file_path = "G:\\Project Machine Learning\\Lending_Club_Loan_Status_Data\\LCDataDictionary.xlsx"
start_time = time.time()
dataset_loan = pd.read_excel(file_path, engine = "calamine", nrows = 100000)
print("%s" ,time.time()-start_time)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-e35e1dcaeeb1> in <module>
#       1 file_path = "G:\\Project Machine Learning\\Lending_Club_Loan_Status_Data\\LCDataDictionary.xlsx"
#       2 start_time = time.time()
# ----> 3 dataset_loan = pd.read_excel(file_path, engine = "calamine", nrows = 100000)
#       4 print("%s" ,time.time()-start_time)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : 2cb96529396d93b46abab7bbc73a208e708c642e
# python           : 3.8.8.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# Version          : 10.0.19041
# machine          : AMD64
# processor        : AMD64 Family 23 Model 17 Stepping 0, AuthenticAMD
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : English_India.1252
#
# pandas           : 1.2.4
# numpy            : 1.20.1
# pytz             : 2021.1
# dateutil         : 2.8.1
# pip              : 21.0.1
# setuptools       : 52.0.0.post20210125
# Cython           : 0.29.23
# pytest           : 6.2.3
# hypothesis       : None
# sphinx           : 4.0.1
# blosc            : None
# feather          : None
# xlsxwriter       : 1.3.8
# lxml.etree       : 4.6.3
# html5lib         : 1.1
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.11.3
# IPython          : 7.22.0
# ...

# %%
pip list --outdated
# Out:
# Package                       Version             Latest      TypeNote: you may need to restart the kernel to use updated packages.
# ----------------------------- ------------------- ----------- -----
# alabaster                     0.7.12              0.7.13      wheel
# anyio                         2.2.0               4.4.0       wheel
# argh                          0.26.2              0.31.3      wheel
# argon2-cffi                   20.1.0              23.1.0      wheel
# asn1crypto                    1.4.0               1.5.1       wheel
# astroid                       2.5                 3.2.4       wheel
# astropy                       4.2.1               5.2.2       wheel
# atomicwrites                  1.4.0               1.4.1       sdist
#
# attrs                         20.3.0              24.2.0      wheel
# autopep8                      1.5.6               2.3.1       wheel
# Babel                         2.9.0               2.16.0      wheel
# ...

# %%
# !python --version
# Out:
# Python 3.8.8

# %%
jupyter kernelspec list
# Out:
#   File "<ipython-input-14-68dcfb427789>", line 1
#     jupyter kernelspec list
#             ^
# SyntaxError: invalid syntax
